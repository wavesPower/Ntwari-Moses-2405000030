# %% [markdown]
# <a href="https://colab.research.google.com/github/wavesPower/Ntwari-Moses-2405000030/blob/main/NTWARI_Moses_2405000030.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import json


# !pip3 install requests
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.7.9)

# %% [markdown]
# [link text](https://)

# %% [markdown]
# result = requests.get('https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow')
# print(result)

# %%
result = requests.get('https://api.stackexchange.com/2.3/questions?order=desc&sort=activity&site=stackoverflow')
print(result)
# Out:
# <Response [200]>

# %%
print(result.json())
# Out:
# {'items': [{'tags': ['php', 'sql', 'mysql', 'installation'], 'owner': {'account_id': 1281721, 'reputation': 508, 'user_id': 1235692, 'user_type': 'registered', 'accept_rate': 100, 'profile_image': 'https://i.sstatic.net/2SiSP.jpg?s=256', 'display_name': 'MrLewk', 'link': 'https://stackoverflow.com/users/1235692/mrlewk'}, 'is_answered': False, 'view_count': 129, 'answer_count': 1, 'score': 0, 'last_activity_date': 1752321497, 'creation_date': 1403524700, 'last_edit_date': 1752321364, 'question_id': 24365337, 'content_license': 'CC BY-SA 4.0', 'link': 'https://stackoverflow.com/questions/24365337/what-is-the-most-efficient-way-to-install-a-large-mysql-database', 'title': 'What is the most efficient way to install a large mysql database'}, {'tags': ['java', 'spring-boot', 'gradle', 'port'], 'owner': {'account_id': 3322011, 'reputation': 3877, 'user_id': 9263418, 'user_type': 'registered', 'profile_image': 'https://i.sstatic.net/IOML3.jpg?s=256', 'display_name': 'Anonymous Creator', 'link': 'https://stackoverflow.com/users/9263418/anonymous-creator'}, 'is_answered': True, 'view_count': 474843, 'accepted_answer_id': 56500768, 'answer_count': 27, 'score': 76, 'last_activity_date': 1752321476, 'creation_date': 1559934099, 'last_edit_date': 1724983016, 'question_id': 56499928, 'content_license': 'CC BY-SA 4.0', 'link': 'https://stackoverflow.com/questions/56499928/web-server-failed-to-start-port-8080-was-already-in-use-spring-boot-microservi', 'title': 'Web server failed to start. Port 8080 was already in use. Spring Boot microservice'}, {'tags': ['azure', 'azure-data-factory'], 'owner': {'account_id': 42985111, 'reputation': 1, 'user_id': 31019146, 'user_type': 'registered', 'profile_image': 'https://www.gravatar.com/avatar/d7f160a177363eab46109ae0150074ac?s=256&d=identicon&r=PG&f=y&so-version=2', 'display_name': 'Robbert-Jan Wijnen', 'link': 'https://stackoverflow.com/users/31019146/robbert-jan-wijnen'}, 'is_answered': False, 'view_count': 24, 'answer_count': 1, 'score': 0, 'last_activity_date': 1752321310, 'creation_date': 1752239036, 'question_id': 79698381, 'content_license': 'CC BY-SA 4.0', 'link': 'https://stackoverflow.com/questions/79698381/adf-copy-activity-mapping-complete-object-within-array', 'title': 'ADF copy activity mapping complete object within array'}, {'tags': ['next.js15'], 'owner': {'account_id': 20913430, 'reputation': 475, 'user_id': 15363745, 'user_type': 'registered', 'profile_image': 'https://lh3.googleusercontent.com/a-/AOh14GislpABFT_UcC_hqKBvN8Zmz6iaDZQDNxXRuigz=k-s256', 'display_name': 'Yellow Clock', 'link': 'https://stackoverflow.com/users/15363745/yellow-clock'}, 'is_answered': False, 'view_count': 7, 'answer_count': 0, 'score': 0, 'last_activity_date': 1752321250, 'creation_date': 1752321250, 'question_id': 79699244, 'content_license': 'CC BY-SA 4.0', 'link': 'https://stackoverflow.com/questions/79699244/problem-type-id-string-is-missing-the-following-properties-from-type-p', 'title': 'Problem: Type &#39;{ id: string; }&#39; is missing the following properties from type &#39;Promise&lt;any&gt;'}, {'tags': ['artificial-intelligence', 'openai-api', 'rag'], 'owner': {'account_id': 42991420, 'reputation': 1, 'user_id': 31021949, 'user_type': 'registered', 'profile_image': 'https://www.gravatar.com/avatar/68469a9f459d0691f64c8a4c6d400730?s=256&d=identicon&r=PG&f=y&so-version=2', 'display_name': 'Beni', 'link': 'https://stackoverflow.com/users/31021949/beni'}, 'is_answered': False, 'view_count': 27, 'closed_date': 1752272820, 'answer_count': 0, 'score': -3, 'last_activity_date': 1752321229, 'creation_date': 1752270024, 'last_edit_date': 1752321229, 'question_id': 79698856, 'link': 'https://stackoverflow.com/questions/79698856/best-ai-method-to-read-and-query-a-large-pdf-document', 'closed_reason': 'Not suitable for this site', 'title': 'Best AI method to read and query a large PDF document'}, {'tags': ['react-native'], 'owner': {'account_id': 20065073, 'reputation': 29, 'user_id': 14710917, 'user_type': ' ...

# %%
print(result.json()['items'])
# Out:
# [{'tags': ['php', 'sql', 'mysql', 'installation'], 'owner': {'account_id': 1281721, 'reputation': 508, 'user_id': 1235692, 'user_type': 'registered', 'accept_rate': 100, 'profile_image': 'https://i.sstatic.net/2SiSP.jpg?s=256', 'display_name': 'MrLewk', 'link': 'https://stackoverflow.com/users/1235692/mrlewk'}, 'is_answered': False, 'view_count': 129, 'answer_count': 1, 'score': 0, 'last_activity_date': 1752321497, 'creation_date': 1403524700, 'last_edit_date': 1752321364, 'question_id': 24365337, 'content_license': 'CC BY-SA 4.0', 'link': 'https://stackoverflow.com/questions/24365337/what-is-the-most-efficient-way-to-install-a-large-mysql-database', 'title': 'What is the most efficient way to install a large mysql database'}, {'tags': ['java', 'spring-boot', 'gradle', 'port'], 'owner': {'account_id': 3322011, 'reputation': 3877, 'user_id': 9263418, 'user_type': 'registered', 'profile_image': 'https://i.sstatic.net/IOML3.jpg?s=256', 'display_name': 'Anonymous Creator', 'link': 'https://stackoverflow.com/users/9263418/anonymous-creator'}, 'is_answered': True, 'view_count': 474843, 'accepted_answer_id': 56500768, 'answer_count': 27, 'score': 76, 'last_activity_date': 1752321476, 'creation_date': 1559934099, 'last_edit_date': 1724983016, 'question_id': 56499928, 'content_license': 'CC BY-SA 4.0', 'link': 'https://stackoverflow.com/questions/56499928/web-server-failed-to-start-port-8080-was-already-in-use-spring-boot-microservi', 'title': 'Web server failed to start. Port 8080 was already in use. Spring Boot microservice'}, {'tags': ['azure', 'azure-data-factory'], 'owner': {'account_id': 42985111, 'reputation': 1, 'user_id': 31019146, 'user_type': 'registered', 'profile_image': 'https://www.gravatar.com/avatar/d7f160a177363eab46109ae0150074ac?s=256&d=identicon&r=PG&f=y&so-version=2', 'display_name': 'Robbert-Jan Wijnen', 'link': 'https://stackoverflow.com/users/31019146/robbert-jan-wijnen'}, 'is_answered': False, 'view_count': 24, 'answer_count': 1, 'score': 0, 'last_activity_date': 1752321310, 'creation_date': 1752239036, 'question_id': 79698381, 'content_license': 'CC BY-SA 4.0', 'link': 'https://stackoverflow.com/questions/79698381/adf-copy-activity-mapping-complete-object-within-array', 'title': 'ADF copy activity mapping complete object within array'}, {'tags': ['next.js15'], 'owner': {'account_id': 20913430, 'reputation': 475, 'user_id': 15363745, 'user_type': 'registered', 'profile_image': 'https://lh3.googleusercontent.com/a-/AOh14GislpABFT_UcC_hqKBvN8Zmz6iaDZQDNxXRuigz=k-s256', 'display_name': 'Yellow Clock', 'link': 'https://stackoverflow.com/users/15363745/yellow-clock'}, 'is_answered': False, 'view_count': 7, 'answer_count': 0, 'score': 0, 'last_activity_date': 1752321250, 'creation_date': 1752321250, 'question_id': 79699244, 'content_license': 'CC BY-SA 4.0', 'link': 'https://stackoverflow.com/questions/79699244/problem-type-id-string-is-missing-the-following-properties-from-type-p', 'title': 'Problem: Type &#39;{ id: string; }&#39; is missing the following properties from type &#39;Promise&lt;any&gt;'}, {'tags': ['artificial-intelligence', 'openai-api', 'rag'], 'owner': {'account_id': 42991420, 'reputation': 1, 'user_id': 31021949, 'user_type': 'registered', 'profile_image': 'https://www.gravatar.com/avatar/68469a9f459d0691f64c8a4c6d400730?s=256&d=identicon&r=PG&f=y&so-version=2', 'display_name': 'Beni', 'link': 'https://stackoverflow.com/users/31021949/beni'}, 'is_answered': False, 'view_count': 27, 'closed_date': 1752272820, 'answer_count': 0, 'score': -3, 'last_activity_date': 1752321229, 'creation_date': 1752270024, 'last_edit_date': 1752321229, 'question_id': 79698856, 'link': 'https://stackoverflow.com/questions/79698856/best-ai-method-to-read-and-query-a-large-pdf-document', 'closed_reason': 'Not suitable for this site', 'title': 'Best AI method to read and query a large PDF document'}, {'tags': ['react-native'], 'owner': {'account_id': 20065073, 'reputation': 29, 'user_id': 14710917, 'user_type': 'registered ...

# %%
for questions in result.json()['items']:

    print(questions['title'])
    print(questions['link'])
    print()
# Out:
# What is the most efficient way to install a large mysql database
# https://stackoverflow.com/questions/24365337/what-is-the-most-efficient-way-to-install-a-large-mysql-database
#
# Web server failed to start. Port 8080 was already in use. Spring Boot microservice
# https://stackoverflow.com/questions/56499928/web-server-failed-to-start-port-8080-was-already-in-use-spring-boot-microservi
#
# ADF copy activity mapping complete object within array
# https://stackoverflow.com/questions/79698381/adf-copy-activity-mapping-complete-object-within-array
#
# Problem: Type &#39;{ id: string; }&#39; is missing the following properties from type &#39;Promise&lt;any&gt;
# https://stackoverflow.com/questions/79699244/problem-type-id-string-is-missing-the-following-properties-from-type-p
#
# Best AI method to read and query a large PDF document
# https://stackoverflow.com/questions/79698856/best-ai-method-to-read-and-query-a-large-pdf-document
#
# React Native iOS pod issue
# https://stackoverflow.com/questions/79699181/react-native-ios-pod-issue
#
# How to link the Autocomplete dropdown item to a subsection of same page without displaying full url name
# https://stackoverflow.com/questions/79699186/how-to-link-the-autocomplete-dropdown-item-to-a-subsection-of-same-page-without
#
# Getting write operation failed warning with refs
# https://stackoverflow.com/questions/77951785/getting-write-operation-failed-warning-with-refs
#
# how can i code in godot 4.3 that if enemy just see main player then play a animation?
# https://stackoverflow.com/questions/79699242/how-can-i-code-in-godot-4-3-that-if-enemy-just-see-main-player-then-play-a-anima
#
# How to get the ID from URL using Playwright?
# https://stackoverflow.com/questions/79698928/how-to-get-the-id-from-url-using-playwright
#
# Why WebTransport cannot connect to my server?
# https://stackoverflow.com/questions/79699241/why-webtransport-cannot-connect-to-my-server
#
# VS Code Python extension injects incorrect start up script oh-my-posh variables with shell integration
# https://stackoverflow.com/questions/79699240/vs-code-python-extension-injects-incorrect-start-up-script-oh-my-posh-variables
#
# Is the finish awaited process executed using multi thread or interrupt function in this scenario
# https://stackoverflow.com/questions/79699227/is-the-finish-awaited-process-executed-using-multi-thread-or-interrupt-function
#
# Type Checking in Vite/React Project: Why do I need tsc when tsserver is already working?
# https://stackoverflow.com/questions/79699180/type-checking-in-vite-react-project-why-do-i-need-tsc-when-tsserver-is-already
#
# Django cannot create record with correct foreign key to CharField with spaces in middle - getting surrounded by single and double quotes like &quot;&#39;a a&#39;&quot;
# https://stackoverflow.com/questions/79699235/django-cannot-create-record-with-correct-foreign-key-to-charfield-with-spaces-in
#
# How to properly remove outliers in sensor data?
# https://stackoverflow.com/questions/79699237/how-to-properly-remove-outliers-in-sensor-data
#
# Is there any possible way of using gpu for AI/ML purposes in laptops which dont have nvidia chip set or any other alternative way?
# https://stackoverflow.com/questions/79699238/is-there-any-possible-way-of-using-gpu-for-ai-ml-purposes-in-laptops-which-dont
#
# Java awt TextArea messes up the window size
# https://stackoverflow.com/questions/79698880/java-awt-textarea-messes-up-the-window-size
#
# Not able to call FastMCP server using http or SSE protocol
# https://stackoverflow.com/questions/79698941/not-able-to-call-fastmcp-server-using-http-or-sse-protocol
#
# why Argoworkflows multi-app-docker-build image with kaniko fails
# https://stackoverflow.com/questions/79699234/why-argoworkflows-multi-app-docker-build-image-with-kaniko-fails
#
# Cleaning VSCode profiles Folder &amp; Workspaces
# https://stackoverflow.com/questions/79272316/cleaning-vscode-profiles-folder-workspaces
#
# Import module installed with npm without node.js
# https://stackoverflow.com/questions/79699231/import-module-installed-with-npm-without-node-js
#
# How to prevent filtered component from re-rendering over and over?
# https://stackoverflow.com/questions/79674218/how-to-prevent-filtered-component-from-re-rendering-over-and-over
#
# Cannot load FastAI .pkl model locally due to missing AMPMode and module version issues
# https://stackoverflow.com/questions/79698656/cannot-load-fastai-pkl-model-locally-due-to-missing-ampmode-and-module-version
#
# SAS: Conditionally summing a column without having the lead funtion
# https://stackoverflow.com/questions/79696592/sas-conditionally-summing-a-column-without-having-the-lead-funtion
#
# Will requests to my site lag and work slowly in django while waiting for celery results?
# https://stackoverflow.com/questions/79698019/will-requests-to-my-site-lag-and-work-slowly-in-django-while-waiting-for-celery
#
# CodeIgniter: Unknown column xxx in ‘where clause’
# https://stackoverflow.com/questions/1654778/codeigniter-unknown-column-xxx-in-where-clause
#
# How to use relative path to get file in C drive but the current program file is in D drive?
# https://stackoverflow.com/questions/79699163/how-to-use-relative-path-to-get-file-in-c-drive-but-the-current-program-file-is
#
# Why does this CMake list variable expansion not behave as expected?
# https://stackoverflow.com/questions/79693529/why-does-this-cmake-list-variable-expansion-not-behave-as-expected
#
# vue data isn`t displayed on a page
# https://stackoverflow.com/questions/77666567/vue-data-isnt-displayed-on-a-page
